# %% [markdown]
# <a href="https://colab.research.google.com/github/mcc2415-commits/BTE320/blob/main/BTE320.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
def greet():
  print('H')
  print('E')
  print('L')
  print('L')
  print('O')
  print('!')

# %%
greet();
# Out:
# H
# E
# L
# L
# O
# !
